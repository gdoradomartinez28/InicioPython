# %% [markdown]
# <a href="https://colab.research.google.com/github/gdoradomartinez28/InicioPython/blob/main/nombreyedad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nombre = input("¿Como te llamas? ")
año_nacimiento = int(input("¿En que año naciste? "))
edad = 2026 - año_nacimiento
print(f"Hola {nombre}, naciste en {año_nacimiento} y tienes {edad} años")
# Out:
# ¿Como te llamas? Gabriel
# ¿En que año naciste? 2006
# Hola Gabriel, naciste en 2006 y tienes 20 años
